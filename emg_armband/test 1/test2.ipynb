# %%
import argparse
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data.csv")

####### plot the data #######

# Create a single figure with subplots
fig, axes = plt.subplots(8, 1, figsize=(20, 14))

for row in range(0, 8):
    data = []
    for x in range(df.shape[1]):
        data.append(df.iloc[row, x])

    axes[row].plot(data)  # Use the respective subplot for each row
    axes[row].set_title(f"Channel {row + 1}")

#plt.tight_layout()  # Adjusts spacing between subplots
plt.show()

# %%
import argparse
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import mindrove
from mindrove.board_shim import BoardShim, MindRoveInputParams, BoardIds
from mindrove.data_filter import DataFilter, FilterTypes, AggOperations

help(DataFilter)
# Out:
# Help on class DataFilter in module mindrove.data_filter:
#
# class DataFilter(builtins.object)
#  |  DataFilter class contains methods for signal processig
#  |
#  |  Class methods defined here:
#  |
#  |  calc_stddev(data: nptyping.types._ndarray.NDArray) from builtins.type
#  |      calc stddev
#  |
#  |      :param data: input array
#  |      :type data: NDArray[Float64]
#  |      :return: stddev
#  |      :rtype: float
#  |
#  |  detrend(data: nptyping.types._ndarray.NDArray, detrend_operation: int) -> None from builtins.type
#  |      detrend data
#  |
#  |      :param data: data to calc psd
#  |      :type data: NDArray[Float64]
#  |      :param detrend_operation: Type of detrend operation
#  |      :type detrend_operation: int
#  |
#  |  disable_data_logger() -> None from builtins.type
#  |      disable Data Logger
#  |
#  |  enable_data_logger() -> None from builtins.type
#  |      enable Data Logger with level INFO, uses stderr for log messages by default
#  |
#  |  enable_dev_data_logger() -> None from builtins.type
#  |      enable Data Logger with level TRACE, uses stderr for log messages by default
#  |
#  |  get_avg_band_powers(data: nptyping.types._ndarray.NDArray, channels: List, sampling_rate: int, apply_filter: bool) -> Tuple from builtins.type
#  |      calculate avg and stddev of BandPowers across all channels, bands are 1-4,4-8,8-13,13-30,30-50
#  |
#  |      :param data: 2d array for calculation
#  |      :type data: NDArray
#  |      :param channels: channels - rows of data array which should be used for calculation
#  |      :type channels: List
#  |      :param sampling_rate: sampling rate
#  |      :type sampling_rate: int
#  |      :param apply_filter: apply bandpass and bandstop filtrers or not
#  |      :type apply_filter: bool
#  |      :return: avg and stddev arrays for bandpowers
#  |      :rtype: tuple
#  |
#  |  get_band_power(psd: Tuple, freq_start: float, freq_end: float) -> float from builtins.type
#  |      calculate band power
#  |
#  |      :param psd: psd from get_psd
#  |      :type psd: tuple
#  |      :param freq_start: start freq
#  |      :type freq_start: int
#  |      :param freq_end: end freq
#  |      :type freq_end: int
#  |      :return: band power
#  |      :rtype: float
#  |
#  |  get_csp(data: nptyping.types._ndarray.NDArray, labels: nptyping.types._ndarray.NDArray) -> Tuple from builtins.type
#  |      calculate filters and the corresponding eigenvalues using the Common Spatial Patterns
#  |
#  |      :param data: [epochs x channels x times]-shaped 3D array of data for two classes
#  |      :type data: NDArray[Float64]
#  |      :param labels: n_epochs-length 1D array of zeros and ones that assigns class labels for each epoch. Zero corresponds to the first class
#  |      :type labels: NDArray[Int64]
#  |      :return: [channels x channels]-shaped 2D array of filters and [channels]-length 1D array of the corresponding eigenvalues
#  |      :rtype: Tuple
#  |
#  |  get_nearest_power_of_two(value: int) -> int from builtins.type
#  |      calc nearest power of two
#  |
#  |      :param value: input value
#  |      :type value: int
#  |      :return: nearest power of two
#  |      :rtype: int
#  |
#  |  get_psd(data: nptyping.types._ndarray.NDArray, sampling_rate: int, window: int) -> Tuple from builtins.type
#  |      calculate PSD
#  |
#  |      :param data: data to calc psd, len of data must be a power of 2
#  |      :type data: NDArray[Float64]
#  |      :param sampling_rate: sampling rate
#  |      :type sampling_rate: int
#  |      :param window: window function
#  |      :type window: int
#  |      :return: amplitude and frequency arrays of len N / 2 + 1
#  |      :rtype: tuple
#  |
#  |  get_psd_welch(data: nptyping.types._ndarray.NDArray, nfft: int, overlap: int, sampling_rate: int, window: int) -> Tuple from builtins.type
#  |      calculate PSD using Welch method
#  |
#  |      :param data: data to calc psd
#  |      :type data: NDArray[Float64]
#  |      :param nfft: FFT Window size, must be power of 2
#  |      :type nfft: int
#  |      :param overlap: overlap of FFT Windows, must be between 0 and nfft
#  |      :type overlap: int
#  |      :param sampling_rate: sampling rate
#  |      :type sampling_rate: int
#  |      :param window: window function
#  |      :type window: int
#  |      :return: amplitude and frequency arrays of len N / 2 + 1
#  |      :rtype: tuple
#  |
#  |  get_version() -> str from builtins.type
#  |      get version of mindrove libraries
#  |      :return: version
#  |      :rtype: str
#  |      :raises MindRoveError
#  |
#  |  get_window(window_function: int, window_len: int) -> nptyping.types._ndarray.NDArray from builtins.type
#  |      perform data windowing
#  |
#  |      :param window_function: window function
#  |      :type window: int
#  |      :param window_len: len of the window function
#  |      :return: numpy array, len of the array is the same as data
#  |      :rtype: NDArray[Float64]
#  |
#  |  perform_bandpass(data: nptyping.types._ndarray.NDArray, sampling_rate: int, center_freq: float, band_width: float, order: int, filter_type: int, ripple: float) -> None from builtins.type
#  |      apply band pass filter to provided data
#  |
#  |      :param data: data to filter, filter works in-place
#  |      :type data: NDArray[Float64]
#  |      :param sampling_rate: board's sampling rate
#  |      :type sampling_rate: int
#  |      :param center_freq: center frequency
#  |      :type center_freq: float
#  |      :param band_width: band width
#  |      :type band_width: float
#  |      :param order: filter order
#  |      :type order: int
#  |      :param filter_type: filter type from special enum
#  |      :type filter_type: int
#  |      :param ripple: ripple value for Chebyshev filter
#  |      :type ripple: float
#  |
#  |  perform_bandstop(data: nptyping.types._ndarray.NDArray, sampling_rate: int, center_freq: float, band_width: float, order: int, filter_type: int, ripple: float) -> None from builtins.type
#  |      apply band stop filter to provided data
#  |
#  |      :param data: data to filter, filter works in-place
#  |      :type data: NDArray[Float64]
#  |      :param sampling_rate: board's sampling rate
#  |      :type sampling_rate: int
#  |      :param center_freq: center frequency
#  |      :type center_freq: float
#  |      :param band_width: band width
#  |      :type band_width: float
#  |      :param order: filter order
#  |      :type order: int
#  |      :param filter_type: filter type from special enum
#  |      :type filter_type: int
#  |      :param ripple: ripple value for Chebyshev filter
#  |      :type ripple: float
#  |
#  |  perform_downsampling(data: nptyping.types._ndarray.NDArray, period: int, operation: int) -> nptyping.types._ndarray.NDArray from builtins.type
#  |      perform data downsampling, it doesnt apply lowpass filter for you, it just aggregates several data points
#  |
#  |      :param data: initial data
#  |      :type data: NDArray[Float64]
#  |      :param period: downsampling period
#  |      :type period: int
#  |      :param operation: int value from AggOperation enum
#  |      :type operation: int
#  |      :return: downsampled data
#  |      :rtype: NDArray[Float64]
#  |
#  |  perform_fft(data: nptyping.types._ndarray.NDArray, window: int) -> nptyping.types._ndarray.NDArray from builtins.type
#  |      perform direct fft
#  |
#  |      :param data: data for fft, len of data must be a power of 2
#  |      :type data: NDArray[Float64]
#  |      :param window: window function
#  |      :type window: int
#  |      :return: numpy array of complex values, len of this array is N / 2 + 1
#  |      :rtype: NDArray[Complex128]
#  |
#  |  perform_highpass(data: nptyping.types._ndarray.NDArray, sampling_rate: int, cutoff: float, order: int, filter_type: int, ripple: float) -> None from builtins.type
#  |      apply high pass filter to provided data
#  |
#  |      :param data: data to filter, filter works in-place
#  |      :type data: NDArray[Float64]
#  |      :param sampling_rate: board's sampling rate
#  |      :type sampling_rate: int
#  |      :param cutoff: cutoff frequency
#  |      :type cutoff: float
#  |      :param order: filter order
#  |      :type order: int
#  |      :param filter_type: filter type from special enum
#  |      :type filter_type: int
#  |      :param ripple: ripple value for Chebyshev filter
#  |      :type ripple: float
#  |
#  |  perform_ifft(data: nptyping.types._ndarray.NDArray) -> nptyping.types._ndarray.NDArray from builtins.type
#  |      perform inverse fft
#  |
#  |      :param data: data from fft
#  |      :type data: NDArray[Complex128]
#  |      :return: restored data
#  |      :rtype: NDArray[Float64]
#  |
#  |  perform_inverse_wavelet_transform(wavelet_output: Tuple, original_data_len: int, wavelet: str, decomposition_level: int) -> nptyping.types._ndarray.NDArray from builtins.type
#  |      perform wavelet transform
#  |
#  |      :param wavelet_output: tuple of wavelet_coeffs and array with lengths
#  |      :type wavelet_coeffs: tuple
#  |      :param original_data_len: len of signal before wavelet transform
#  |      :type original_data_len: int
#  |      :param wavelet: supported vals: db1..db15,haar,sym2..sym10,coif1..coif5,bior1.1,bior1.3,bior1.5,bior2.2,bior2.4,bior2.6,bior2.8,bior3.1,bior3.3,bior3.5 ,bior3.7,bior3.9,bior4.4,bior5.5,bior6.8
#  |      :type wavelet: str
#  |      :param decomposition_level: level of decomposition
#  |      :type decomposition_level: int
#  |      :return: restored data
#  |      :rtype: NDArray[Float64]
#  |
#  |  perform_lowpass(data: nptyping.types._ndarray.NDArray, sampling_rate: int, cutoff: float, order: int, filter_type: int, ripple: float) -> None from builtins.type
#  |      apply low pass filter to provided data
#  |
#  |      :param data: data to filter, filter works in-place
#  |      :type data: NDArray[Float64]
#  |      :param sampling_rate: board's sampling rate
#  |      :type sampling_rate: int
#  |      :param cutoff: cutoff frequency
#  |      :type cutoff: float
#  |      :param order: filter order
#  |      :type order: int
#  |      :param filter_type: filter type from special enum
#  |      :type filter_type: int
#  |      :param ripple: ripple value for Chebyshev filter
#  |      :type ripple: float
#  |
#  |  perform_rolling_filter(data: nptyping.types._ndarray.NDArray, period: int, operation: int) -> None from builtins.type
#  |      smooth data using moving average or median
#  |
#  |      :param data: data to smooth, it works in-place
#  |      :type data: NDArray[Float64]
#  |      :param period: window size
#  |      :type period: int
#  |      :param operation: int value from AggOperation enum
#  |      :type operation: int
#  |
#  |  perform_wavelet_denoising(data: nptyping.types._ndarray.NDArray, wavelet: str, decomposition_level: int) -> None from builtins.type
#  |      perform wavelet denoising
#  |
#  |      :param data: data to denoise
#  |      :type data: NDArray[Float64]
#  |      :param wavelet: supported vals: db1..db15,haar,sym2..sym10,coif1..coif5,bior1.1,bior1.3,bior1.5,bior2.2,bior2.4,bior2.6,bior2.8,bior3.1,bior3.3,bior3.5 ,bior3.7,bior3.9,bior4.4,bior5.5,bior6.8
#  |      :type wavelet: str
#  |      :param decomposition_level: decomposition level
#  |      :type decomposition_level: int
#  |
#  |  perform_wavelet_transform(data: nptyping.types._ndarray.NDArray, wavelet: str, decomposition_level: int) -> Tuple from builtins.type
#  |      perform wavelet transform
#  |
#  |      :param data: initial data
#  |      :type data: NDArray[Float64]
#  |      :param wavelet: supported vals: db1..db15,haar,sym2..sym10,coif1..coif5,bior1.1,bior1.3,bior1.5,bior2.2,bior2.4,bior2.6,bior2.8,bior3.1,bior3.3,bior3.5 ,bior3.7,bior3.9,bior4.4,bior5.5,bior6.8
#  |      :type wavelet: str
#  |      :param decomposition_level: level of decomposition
#  |      :type decomposition_level: int
#  |      :return: tuple of wavelet coeffs in format [A(J) D(J) D(J-1) ..... D(1)] where J is decomposition level, A - app coeffs, D - detailed coeffs, and array with lengths for each block
#  |      :rtype: tuple
#  |
#  |  read_file(file_name: str) from builtins.type
#  |      read data from file
#  |
#  |      :param file_name: file name to read
#  |      :type file_name: str
#  |      :return: 2d numpy array with data from this file, data will be transposed to original dimensions
#  |      :rtype: 2d numpy array
#  |
#  |  remove_environmental_noise(data: nptyping.types._ndarray.NDArray, sampling_rate: int, noise_type: float) -> None from builtins.type
#  |      remove env noise using notch filter
#  |
#  |      :param data: data to filter, filter works in-place
#  |      :type data: NDArray[Float64]
#  |      :param sampling_rate: board's sampling rate
#  |      :type sampling_rate: int
#  |      :param noise_type: noise type
#  |      :type noise_type: int
#  |
#  |  set_log_file(log_file: str) -> None from builtins.type
#  |      redirect logger from stderr to file, can be called any time
#  |
#  |      :param log_file: log file name
#  |      :type log_file: str
#  |
#  |  write_file(data, file_name: str, file_mode: str) -> None from builtins.type
#  |      write data to file, in file data will be transposed
#  |
#  |      :param data: data to store in a file
#  |      :type data: 2d numpy array
#  |      :param file_name: file name to store data
#  |      :type file_name: str
#  |      :param file_mode: 'w' to rewrite file or 'a' to append data to file
#  |      :type file_mode: str
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
