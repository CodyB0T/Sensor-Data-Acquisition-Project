# %% [markdown]
# ## plot_emg data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data/data_eeg.csv")
# Create a single figure with subplots
fig, axes = plt.subplots(8, 1, figsize=(25, 18))

for row in range(0, 8):
    data = []
    for x in range(df.shape[1]):
        data.append(df.iloc[row, x])

    axes[row].plot(data)  # Use the respective subplot for each row
    axes[row].set_title(f"Channel {row + 1} 25 frames per seconds")

plt.show()

# %% [markdown]
# ### FFT of emg

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data/data_eeg.csv")

fig, axes = plt.subplots(2, 1, figsize=(20, 8))

data = df.iloc[0,:].tolist()
data = np.array(data)
data = data * 0.000000045
mean = np.mean(data)
data = data - mean

axes[0].plot(data)
axes[0].set_title("Channel 0 data")

fft_result = np.fft.fft(data)
mag = np.abs(fft_result)

sampling_freq = 500  # Example sampling frequency in Hz
freq = np.fft.fftfreq(len(data), d=1.0/sampling_freq)

axes[1].plot(freq, mag)
axes[1].set_title("Channel 0 FFT")
# Out:
# Text(0.5, 1.0, 'Channel 0 FFT')

# %% [markdown]
# ### plot armband imu data

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data/data_imu.csv")

fig, ax = plt.subplots(3, 1, figsize=(20,10))

x=df.iloc[0].values
y=df.iloc[1].values
z=df.iloc[2,220:-1].values


ax[0].plot(x)
ax[0].set_title("armband x")

ax[1].plot(y)
ax[1].set_title("armband y")

ax[2].plot(z*.000061035)
ax[2].set_title("armband z")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[7], line 4
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 4 df = pd.read_csv("data/data_imu.csv")
#       6 fig, ax = plt.subplots(3, 1, figsize=(20,10))
#       8 x=df.iloc[0].values
#
# File c:\Users\codyh\miniconda3\envs\myenv\lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\codyh\miniconda3\envs\myenv\lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\codyh\miniconda3\envs\myenv\lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\codyh\miniconda3\envs\myenv\lib\site-packages\pandas\io\parsers\readers.py:1723, in TextFileReader._make_engine(self, f, engine)
#    1720     raise ValueError(msg)
#    1722 try:
# -> 1723     return mapping[engine](f, **self.options)
#    1724 except Exception:
#    1725     if self.handles is not None:
#
# File c:\Users\codyh\miniconda3\envs\myenv\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:586, in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file

# %% [markdown]
# ## plot shimmer imu

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data/shimmer_data.csv")
df

fig, ax = plt.subplots(3, 1, figsize=(20,10))

x=df.iloc[0].values
y=df.iloc[1].values
z=df.iloc[2].values


ax[0].plot(x)
ax[0].set_title("shimmer x")

ax[1].plot(y)
ax[1].set_title("shimmer y")

ax[2].plot((z - 2084)/367.5)
ax[2].set_title("shimmer z")

# 4096

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data/shimmer_data2.csv")
df

fig, ax = plt.subplots(3, 1, figsize=(20,10))

x=df.iloc[0].values
y=df.iloc[1].values
z=df.iloc[2].values


ax[0].plot((x - 2084)/367.5)
ax[0].set_title("shimmer x")

ax[1].plot((y - 2084)/367.5)
ax[1].set_title("shimmer y")

ax[2].plot((z - 2084)/367.5)
ax[2].set_title("shimmer z")

# 4096

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

shim = pd.read_csv("data/shimmer_data.csv")
shim2 = pd.read_csv("data/shimmer_data2.csv")

shim_z=shim.iloc[2].values
shim2_z=shim2.iloc[2].values

# fig, ax = plt.subplots(3, 1, figsize=(20,10))

plt.plot(shim_z)
plt.plot(shim2_z+2000)
plt.legend(["shim","shim2"])

# shim_x=shim.iloc[2,200].values
# x = 2000
# shim_x=shim.iloc[0,x]
# shim_y=shim.iloc[1,x]
# shim_z=shim.iloc[2,x]
# print(shim_x, shim_y, shim_z)

#1681 = +-9.8
#2060 = 0

# %%
import pandas as pd
import matplotlib.pyplot as plt

shim = pd.read_csv("data/shimmer_data.csv")
arm = pd.read_csv("data/data_imu.csv")

shim_z=shim.iloc[2].values
arm_z=arm.iloc[2,220:-1].values

# fig, ax = plt.subplots(3, 1, figsize=(20,10))

plt.plot(shim_z*2)
plt.plot((arm_z*-0.07)+4500)
plt.legend(["shim","arm"])

# shim_x=shim.iloc[2,200].values
x = 200
shim_x=shim.iloc[0,x]
shim_y=shim.iloc[1,x]
shim_z=shim.iloc[2,x]
print(shim_x, shim_y, shim_z)

#1681 = +-9.8
#2060 = 0
# Out:
# 2066 2062 1681

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
shim = pd.read_csv("data/shimmer_data.csv")


shim.shape
# Out:
# (4, 4753)

# %% [markdown]
# ## denoise using rolling function

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data/shimmer_data.csv")

x=df.iloc[0].values
y=df.iloc[1].values
z=df.iloc[2].values

pct_z = df.iloc[2].rolling(window=5).mean().values

fig, ax = plt.subplots(2,1, figsize = (20,10))

ax[0].plot(z)
ax[1].plot(pct_z)



plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data/shimmer_data.csv")

x=df.iloc[0].values
y=df.iloc[1].values
z=df.iloc[2].values

pct_z = df.iloc[2].rolling(window=5).mean().values

fig, ax = plt.subplots(2,1, figsize = (20,10))

ax[0].plot(z)
ax[1].plot(pct_z)



plt.show()
