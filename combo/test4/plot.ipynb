# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.animation import PillowWriter

df = pd.read_csv("data/data_emg.csv")
# Create a single figure with subplots
fig, axes = plt.subplots(8, 1, figsize=(25, 18))

for row in range(0, 8):
    data = []
    for x in range(df.shape[1]):
        data.append(df.iloc[row, x])

    axes[row].plot(data)  # Use the respective subplot for each row
    axes[row].set_title(f"Channel {row + 1} 25 frames per seconds")

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data/data_emg.csv")
# Create a single figure with subplots

plt.figure(figsize=(40, 6))

data = []
for x in range(df.shape[1]):
    data.append(df.iloc[2, x])


plt.plot(data)

plt.show()
# Out:
# 2500

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

df = pd.read_csv("data/data_emg.csv")
# Create a single figure with subplots

plt.figure(figsize=(40, 6))

data_list = []
for x in range(df.shape[1]):
    data_list.append(df.iloc[2, x])


# Assuming data_list is your list of data
# data_list = [1, 3, 5, 7, 9, 11, 13, 15]

# Create a figure and axis
fig, ax = plt.subplots(figsize=(40, 6))
line, = ax.plot([], [], 'b-')

# Function to initialize the plot
def init():
    ax.set_xlim(0, len(data_list))
    ax.set_ylim(0, max(data_list) + 1)
    return line,

# Function to update the plot
def update(frame):
    if frame < len(data_list):
        x = np.arange(0, frame + 1)
        y = data_list[:frame + 1]
        line.set_data(x, y)
    return line,

# Create animation
ani = FuncAnimation(fig, update, frames=len(data_list) + 1, init_func=init, blit=True, interval = .002)

# Save animation as GIF
ani.save('live_plot.gif', writer='pillow', fps = None)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.animation import FuncAnimation

# Assuming data_list is your list of data
data_list = [1, 3, 5, 7, 9, 11, 13, 15]

# Create a figure and axis
fig, ax = plt.subplots()
line, = ax.plot([], [], 'b-')

# Function to initialize the plot
def init():
    ax.set_xlim(0, len(data_list))
    ax.set_ylim(0, max(data_list) + 1)
    return line,

# Function to update the plot
def update(frame):
    if frame < len(data_list):
        x = np.arange(0, frame + 1)
        y = data_list[:frame + 1]
        line.set_data(x, y)
    return line,

# Create animation
ani = FuncAnimation(fig, update, frames=len(data_list) + 1, init_func=init, blit=True)

# Save animation as GIF
ani.save('live_plot.gif', writer='pillow', fps=1)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# Create a figure and axis
fig, ax = plt.subplots()
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)
line, = ax.plot(x, y)

# Function to update the plot
def update(frame):
    line.set_ydata(np.sin(x + 0.1 * frame))
    return line,

# Create animation
ani = FuncAnimation(fig, update, frames=100, interval=50)

# Display the animation
plt.show()
