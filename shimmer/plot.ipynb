# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


# Plot the data
data = pd.read_csv('data.csv')
print(len(data))
plt.plot(data)

#0:00:14.988988
# Out:
# 6612

# %%
x = 530  # what sampling freq

hz = round(32768/x)
hex_hz = hex(hz)

print(hz)
print(hex_hz)
# Out:
# 62
# 0x3e
